# %% [markdown]
# # Optimal Trader Joe's Grocery List

# %%
pip install pulp --quiet
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pulp import LpProblem, LpVariable, LpMinimize, lpSum, LpStatus

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv('nutrition_prices.csv')
data
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_44785/2670820770.py:1: DtypeWarning: Columns (2,10,11,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('nutrition_prices.csv')
#        Unnamed: 0.1      Unnamed: 0         serving_size  calories  total_fat  \
# 0                 0               0        2 tbsp. (28g)      70.0        7.0
# 1               225             225       0.8 cup (170g)     110.0        0.0
# 2               818             818   1 container (150g)     130.0        0.0
# 3              1407            1407   1 container (150g)     130.0        0.0
# 4              1993            1993  1 1-inch cube (28g)     120.0       10.0
# ...             ...             ...                  ...       ...        ...
# 59019        619083  9 pieces (30g)                120.0       1.5        0.5
# 59020        619084  9 pieces (30g)                120.0       1.5        0.5
# 59021        619085  9 pieces (30g)                120.0       1.5        0.5
# 59022        619086  9 pieces (30g)                120.0       1.5        0.5
# 59023        619087  9 pieces (30g)                120.0       1.5        0.5
#
#        saturated_fat  trans_fat  cholesterol  sodium  total_carbohydrates  \
# 0                5.0        0.0         20.0    70.0                  1.0
# 1                0.0        0.0         10.0    75.0                  7.0
# 2                0.0        0.0          5.0    60.0                 18.0
# 3                0.0        0.0          5.0    60.0                 18.0
# 4                7.0        0.0         30.0   270.0                  0.0
# ...              ...        ...          ...     ...                  ...
# 59019            0.0        5.0         80.0    27.0                  1.0
# 59020            0.0        5.0         80.0    27.0                  1.0
# 59021            0.0        5.0         80.0    27.0                  1.0
# 59022            0.0        5.0         80.0    27.0                  1.0
# 59023            0.0        5.0         80.0    27.0                  1.0
#
#       dietary_fiber sugars  protein  vitamin_d  calcium  iron     potassium  \
# 0                 0    0.5      2.0        0.0     52.0   0.0             0
# 1                 0      5     17.0        0.0    190.0   0.0           240
# 2                 0     15     11.0        0.8    130.0   0.4           188
# 3                 0     15     12.0        0.8    130.0   0.4           188
# 4                 0      0      8.0        0.0    260.0   0.0             0
# ...             ...    ...      ...        ...      ...   ...           ...
# 59019          11.0    0.5      NaN        NaN      NaN  20.0  Churro Bites
# 59020          11.0    0.5      NaN        NaN      NaN  20.0  Churro Bites
# 59021          11.0    0.5      NaN        NaN      NaN  20.0  Churro Bites
# 59022          11.0    0.5      NaN        NaN      NaN  20.0  Churro Bites
# 59023          11.0    0.5      NaN        NaN      NaN  20.0  Churro Bites
#
#                                             item                  item_title  \
# 0                 "Stracciatella" Burata Filling             Burrata Filling
# 1                 0% Greek Yogurt, Nonfat, Plain   Nonfat Plain Greek Yogurt
# 2                 0% Milkfat Greek Nonfat Yogurt           Greek Spanakopita
# 3      0% Milkfat Strawberry Greek Nonfat Yogurt  Sparkling Strawberry Juice
# 4                         1,000 Day Gouda Cheese       1000 Day Gouda Cheese
# ...                                          ...                         ...
# 59019                       Mac and Cheese Bites                        3.99
# 59020                       Mac and Cheese Bites                        3.99
# 59021                       Mac and Cheese Bites                        3.99
# 59022                       Mac and Cheese Bites                        3.99
# 59023                       Mac and Cheese Bites                         NaN
#
#        retail_price
# 0              4.49
# 1              0.99
# 2              4.49
# 3              3.99
# 4             12.99
# ...             ...
# 59019           NaN
# 59020           NaN
# 59021           NaN
# 59022           NaN
# 59023           NaN
#
# [59024 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59024 entries, 0 to 59023
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0.1         59024 non-null  int64
#  1   Unnamed: 0           27772 non-null  object
#  2   serving_size         27702 non-null  object
#  3   calories             58953 non-null  float64
#  4   total_fat            58430 non-null  float64
#  5   saturated_fat        58415 non-null  float64
#  6   trans_fat            58412 non-null  float64
#  7   cholesterol          59004 non-null  float64
#  8   sodium               59021 non-null  float64
#  9   total_carbohydrates  58429 non-null  float64
#  10  dietary_fiber        58415 non-null  object
#  11  sugars               59013 non-null  object
#  12  protein              22707 non-null  float64
#  13  vitamin_d            23205 non-null  float64
#  14  calcium              23204 non-null  float64
#  15  iron                 32473 non-null  float64
#  16  potassium            58969 non-null  object
#  17  item                 59021 non-null  object
#  18  item_title           59018 non-null  object
#  19  retail_price         174 non-null    float64
# dtypes: float64(12), int64(1), object(7)
# memory usage: 9.0+ MB

# %% [markdown]
# ## Cleaning Data

# %%
columns_to_drop = ['Unnamed: 0.1', 'Unnamed: 0']
nutrition_data_cleaned = data.drop(columns=columns_to_drop)

# %%
numeric_columns = ['dietary_fiber', 'sugars', 'potassium']
for col in numeric_columns:
    nutrition_data_cleaned[col] = pd.to_numeric(nutrition_data_cleaned[col], errors='coerce')

# %%
critical_columns = ['calories', 'protein', 'retail_price', 'calcium', 'iron', 'potassium']
nutrition_data_cleaned = nutrition_data_cleaned.dropna(subset=critical_columns)

# %%
nutrition_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 0 to 175
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   serving_size         85 non-null     object
#  1   calories             85 non-null     float64
#  2   total_fat            85 non-null     float64
#  3   saturated_fat        84 non-null     float64
#  4   trans_fat            83 non-null     float64
#  5   cholesterol          84 non-null     float64
#  6   sodium               85 non-null     float64
#  7   total_carbohydrates  85 non-null     float64
#  8   dietary_fiber        85 non-null     float64
#  9   sugars               85 non-null     float64
#  10  protein              85 non-null     float64
#  11  vitamin_d            85 non-null     float64
#  12  calcium              85 non-null     float64
#  13  iron                 85 non-null     float64
#  14  potassium            85 non-null     float64
#  15  item                 85 non-null     object
#  16  item_title           85 non-null     object
#  17  retail_price         85 non-null     float64
# dtypes: float64(15), object(3)
# memory usage: 12.6+ KB

# %%
columns_to_check = ['total_fat', 'total_carbohydrates', 'vitamin_d', 'sodium', 'dietary_fiber', 'sugars']
for col in columns_to_check:
    nutrition_data_cleaned[col].fillna(0, inplace=True)
# Out:
# /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/ipykernel_44785/2889761469.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nutrition_data_cleaned[col].fillna(0, inplace=True)

# %%
nutrition_data_cleaned = nutrition_data_cleaned[
    (nutrition_data_cleaned['calories'] > 0) &
    (nutrition_data_cleaned['protein'] > 0) &
    (nutrition_data_cleaned['retail_price'] > 0)
]

# %%
nutrition_data_cleaned
# Out:
#             serving_size  calories  total_fat  saturated_fat  trans_fat  \
# 0          2 tbsp. (28g)      70.0        7.0            5.0        0.0
# 1         0.8 cup (170g)     110.0        0.0            0.0        0.0
# 2     1 container (150g)     130.0        0.0            0.0        0.0
# 3     1 container (150g)     130.0        0.0            0.0        0.0
# 4    1 1-inch cube (28g)     120.0       10.0            7.0        0.0
# ..                   ...       ...        ...            ...        ...
# 164         1 pack (71g)     380.0       29.0           10.0        0.0
# 169        0.8 cup (51g)     220.0       10.0            4.0        0.0
# 173         1 cup (255g)     310.0       16.0            5.0        1.0
# 174       1 patty (151g)     470.0       39.0           17.0        1.5
# 175        0.3 cup (30g)      60.0        5.0            1.0        0.0
#
#      cholesterol  sodium  total_carbohydrates  dietary_fiber  sugars  protein  \
# 0           20.0    70.0                  1.0            0.0     0.5      2.0
# 1           10.0    75.0                  7.0            0.0     5.0     17.0
# 2            5.0    60.0                 18.0            0.0    15.0     11.0
# 3            5.0    60.0                 18.0            0.0    15.0     12.0
# 4           30.0   270.0                  0.0            0.0     0.0      8.0
# ..           ...     ...                  ...            ...     ...      ...
# 164          0.0   120.0                 23.0            6.0    14.0     16.0
# 169          0.0    15.0                 29.0            4.0     8.0      5.0
# 173         45.0   760.0                 25.0            6.0     5.0     18.0
# 174         95.0    65.0                  0.0            0.0     0.0     28.0
# 175          0.0    90.0                  3.0            2.0     1.0      0.5
#
#      vitamin_d  calcium  iron  potassium  \
# 0          0.0     52.0   0.0        0.0
# 1          0.0    190.0   0.0      240.0
# 2          0.8    130.0   0.4      188.0
# 3          0.8    130.0   0.4      188.0
# 4          0.0    260.0   0.0        0.0
# ..         ...      ...   ...        ...
# 164        0.0    100.0   6.7      450.0
# 169        0.0     26.0   1.8       95.0
# 173        0.0     78.0   5.4      705.0
# 174        0.4     26.0   2.7      376.0
# 175        3.0     20.0   0.2      150.0
#
#                                             item  \
# 0                 "Stracciatella" Burata Filling
# 1                 0% Greek Yogurt, Nonfat, Plain
# 2                 0% Milkfat Greek Nonfat Yogurt
# 3      0% Milkfat Strawberry Greek Nonfat Yogurt
# 4                         1,000 Day Gouda Cheese
# ..                                           ...
# 164  Amped-Up Almonds, Chocolatey Coated Almonds
# 169                Ancient Grains & Nuts Granola
# 173           Angus Beef Chili, with Pinto Beans
# 174             Angus C.B.P. Ground Beef Patties
# 175           Antipasto Mediterranean Vegetables
#
#                                        item_title  retail_price
# 0                                 Burrata Filling          4.49
# 1                       Nonfat Plain Greek Yogurt          0.99
# 2                               Greek Spanakopita          4.49
# 3                      Sparkling Strawberry Juice          3.99
# 4                           1000 Day Gouda Cheese         12.99
# ..                                            ...           ...
# 164                              Amped-Up Almonds          0.01
# 169  Organic Yellow Lentil & Brown Rice Spaghetti          3.49
# 173                             Chevre with Honey          3.29
# 174              Angus C.B.P. Ground Beef Patties          9.99
# 175                          Mediterranean Dorade          3.99
#
# [74 rows x 18 columns]

# %% [markdown]
# ## Optimization Model

# %% [markdown]
# #### Model

# %%
model = LpProblem("Optimal_Grocery_List", LpMinimize)

# %% [markdown]
# #### Binary Decision Variables

# %%
x = {i: LpVariable(f"x_{i}", cat="Binary") for i in nutrition_data_cleaned.index}

# %% [markdown]
# #### Objecvtive Function to Minimize Cost

# %%
model += lpSum(nutrition_data_cleaned.loc[i, 'retail_price'] * x[i] for i in nutrition_data_cleaned.index), "Total Cost"

# %% [markdown]
# #### Constraints

# %%
constraints = {
    "calories": 2200,         
    "protein": 60,            
    "fat_max": 80,             
    "carbohydrate": 250,       
    "sodium_max": 3000,        
    "fiber": 20,              
    "sugar_max": 60,          
    "cholesterol_max": 300,   
    "saturated_fat_max": 20,  
    "vitamin_d": 10,          
    "budget": 250              
}

# %%
# Constraint 1: Calories 
model += lpSum(nutrition_data_cleaned.loc[i, 'calories'] * x[i] for i in nutrition_data_cleaned.index) >= constraints["calories"], "Calorie_Constraint"
# Constraint 2: Protein
model += lpSum(nutrition_data_cleaned.loc[i, 'protein'] * x[i] for i in nutrition_data_cleaned.index) >= constraints["protein"], "Protein_Constraint"
# Constraint 3: Fat
model += lpSum(nutrition_data_cleaned.loc[i, 'total_fat'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["fat_max"], "Fat_Constraint"
# Constraint 4: Carbohydrates
model += lpSum(nutrition_data_cleaned.loc[i, 'total_carbohydrates'] * x[i] for i in nutrition_data_cleaned.index) >= constraints["carbohydrate"], "Carbohydrate_Constraint"
# Constraint 5: Sodium
model += lpSum(nutrition_data_cleaned.loc[i, 'sodium'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["sodium_max"], "Sodium_Constraint"
# Constraint 6: Fiber
model += lpSum(nutrition_data_cleaned.loc[i, 'dietary_fiber'] * x[i] for i in nutrition_data_cleaned.index) >= constraints["fiber"], "Fiber_Constraint"
# Constraint 7: Sugar
model += lpSum(nutrition_data_cleaned.loc[i, 'sugars'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["sugar_max"], "Sugar_Constraint"
# Constraint 8: Cholesterol
model += lpSum(nutrition_data_cleaned.loc[i, 'cholesterol'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["cholesterol_max"], "Cholesterol_Constraint"
# Constraint 9: Saturated Fat
model += lpSum(nutrition_data_cleaned.loc[i, 'saturated_fat'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["saturated_fat_max"], "Saturated_Fat_Constraint"
# Constraint 10: Vitamin D
model += lpSum(nutrition_data_cleaned.loc[i, 'vitamin_d'] * x[i] for i in nutrition_data_cleaned.index) >= constraints["vitamin_d"], "Vitamin_D_Constraint"
# Constraint 11: Budget
model += lpSum(nutrition_data_cleaned.loc[i, 'retail_price'] * x[i] for i in nutrition_data_cleaned.index) <= constraints["budget"], "Budget_Constraint"

# %% [markdown]
# #### Model Solver

# %%
model.solve()
print("Model Status:", LpStatus[model.status])
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/josesalerno/Documents/BU/Semester/Fall-24/BA885/traderjoe/venv/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/43887582c99d40d085133fe2ab92b8c4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/zp/sq6bzsp91fz1sl3107mgk5gc0000gn/T/43887582c99d40d085133fe2ab92b8c4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16 COLUMNS
# At line 867 RHS
# At line 879 BOUNDS
# At line 954 ENDATA
# Problem MODEL has 11 rows, 74 columns and 628 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 29.4853 - 0.00 seconds
# Cgl0004I processed model has 11 rows, 72 columns (72 integer (70 of which binary)) and 616 elements
# Cutoff increment increased from 1e-05 to 0.00999
# Cbc0038I Initial state - 5 integers unsatisfied sum - 0.832219
# Cbc0038I Pass   1: suminf.    0.55137 (3) obj. 30.0636 iterations 8
# Cbc0038I Pass   2: suminf.    0.76161 (3) obj. 33.8186 iterations 3
# Cbc0038I Pass   3: suminf.    0.58894 (2) obj. 31.4624 iterations 2
# Cbc0038I Pass   4: suminf.    0.76161 (3) obj. 33.8186 iterations 2
# Cbc0038I Pass   5: suminf.    1.13173 (5) obj. 55.5669 iterations 17
# Cbc0038I Pass   6: suminf.    0.95960 (3) obj. 56.3319 iterations 4
# Cbc0038I Pass   7: suminf.    0.39953 (3) obj. 56.841 iterations 3
# Cbc0038I Pass   8: suminf.    1.10274 (3) obj. 61.1689 iterations 2
# Cbc0038I Pass   9: suminf.    1.10274 (3) obj. 61.1689 iterations 0
# Cbc0038I Pass  10: suminf.    1.15079 (4) obj. 49.8386 iterations 7
# Cbc0038I Pass  11: suminf.    0.70446 (3) obj. 49.4519 iterations 1
# Cbc0038I Pass  12: suminf.    0.00000 (0) obj. 48.04 iterations 4
# Cbc0038I Solution found of 48.04
# Cbc0038I Cleaned solution of 48.04
# Cbc0038I Before mini branch and bound, 49 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 72 columns, reduced to 8 rows 22 columns
# Cbc0038I Mini branch and bound improved solution from 48.04 to 31.87 (0.02 seconds)
# Cbc0038I Round again with cutoff of 31.6226
# Cbc0038I Reduced cost fixing fixed 44 variables on major pass 2
# Cbc0038I Pass  13: suminf.    0.55137 (3) obj. 30.0636 iterations 0
# Cbc0038I Pass  14: suminf.    0.70472 (3) obj. 29.756 iterations 4
# Cbc0038I Pass  15: suminf.    1.62312 (5) obj. 31.6226 iterations 7
# Cbc0038I Pass  16: suminf.    0.31059 (3) obj. 31.1203 iterations 6
# Cbc0038I Pass  17: suminf.    1.31884 (4) obj. 31.4019 iterations 4
# Cbc0038I Pass  18: suminf.    0.92877 (4) obj. 31.6226 iterations 2
# Cbc0038I Pass  19: suminf.    0.85200 (3) obj. 31.5914 iterations 1
# Cbc0038I Pass  20: suminf.    1.02903 (5) obj. 31.6226 iterations 5
# Cbc0038I Pass  21: suminf.    0.67280 (3) obj. 30.5419 iterations 3
# Cbc0038I Pass  22: suminf.    0.31059 (3) obj. 31.1203 iterations 3
# Cbc0038I Pass  23: suminf.    1.31884 (4) obj. 31.4019 iterations 4
# Cbc0038I Pass  24: suminf.    0.92877 (4) obj. 31.6226 iterations 2
# Cbc0038I Pass  25: suminf.    0.85200 (3) obj. 31.5914 iterations 1
# Cbc0038I Pass  26: suminf.    1.02903 (5) obj. 31.6226 iterations 5
# Cbc0038I Pass  27: suminf.    0.67280 (3) obj. 30.5419 iterations 3
# Cbc0038I Pass  28: suminf.    0.31059 (3) obj. 31.1203 iterations 3
# Cbc0038I Pass  29: suminf.    1.31884 (4) obj. 31.4019 iterations 4
# Cbc0038I Pass  30: suminf.    0.92877 (4) obj. 31.6226 iterations 2
# Cbc0038I Pass  31: suminf.    0.85200 (3) obj. 31.5914 iterations 1
# Cbc0038I Pass  32: suminf.    1.02903 (5) obj. 31.6226 iterations 5
# Cbc0038I Pass  33: suminf.    0.67280 (3) obj. 30.5419 iterations 3
# Cbc0038I Pass  34: suminf.    0.31059 (3) obj. 31.1203 iterations 3
# Cbc0038I Pass  35: suminf.    1.31884 (4) obj. 31.4019 iterations 4
# Cbc0038I Pass  36: suminf.    0.92877 (4) obj. 31.6226 iterations 2
# Cbc0038I Pass  37: suminf.    0.85200 (3) obj. 31.5914 iterations 1
# Cbc0038I Pass  38: suminf.    1.02903 (5) obj. 31.6226 iterations 5
# Cbc0038I Pass  39: suminf.    0.67280 (3) obj. 30.5419 iterations 3
# Cbc0038I Pass  40: suminf.    0.31059 (3) obj. 31.1203 iterations 3
# Cbc0038I Pass  41: suminf.    1.31884 (4) obj. 31.4019 iterations 4
# Cbc0038I Pass  42: suminf.    0.92877 (4) obj. 31.6226 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 58 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 11 rows 72 columns, reduced to 8 rows 13 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 31.87 - took 0.01 seconds
# Cbc0012I Integer solution of 31.87 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 11 rows 72 columns, reduced to 7 rows 6 columns
# Cbc0031I 9 added rows had average density of 16.555556
# Cbc0013I At root node, 9 cuts changed objective from 29.489037 to 31.104829 in 9 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 29 row cuts average 11.3 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 24 row cuts average 40.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 94 row cuts average 18.2 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 31.87 best solution, best possible 31.104829 (0.04 seconds)
# Cbc0001I Search completed - best objective 31.87, took 322 iterations and 6 nodes (0.06 seconds)
# Cbc0032I Strong branching done 60 times (380 iterations), fathomed 0 nodes and fixed 3 variables
# Cbc0035I Maximum depth 2, 71 variables fixed on reduced cost
# Cuts at root node changed objective from 29.4857 to 31.1048
# Probing was tried 9 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 31 times and created 90 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# Clique was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 31 times and created 119 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 31 times and created 296 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 22 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                31.87000000
# Enumerated nodes:               6
# Total iterations:               322
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.06
#
# Model Status: Optimal

# %%
selected_items = [nutrition_data_cleaned.loc[i, 'item_title'] for i in nutrition_data_cleaned.index if x[i].value() == 1]
print("Selected Items:")
for item in selected_items:
    print(item)
# Out:
# Selected Items:
# Nonfat Plain Greek Yogurt
# Whole Wheat Sliced Bread
# 3 Seed Beet Crackers
# Sweet Potato
# Strawberry Waffles
# 4 Cheese Ravioli
# Sprouted Wheat Sourdough Bread
# Wild Skipjack Tuna
# Solid White Albacore Tuna, No Salt Added
# Almond Butter Chia Overnight Oats
# Gluten Free Ginger Turmeric Granola
# Everything But The Bagel Seasoned Potato Chips
# Sweet Pull Apart Aloha Rolls

# %%
total_cost = sum(nutrition_data_cleaned.loc[i, 'retail_price'] for i in nutrition_data_cleaned.index if x[i].value() == 1)
print(f"Total Cost: ${total_cost:.2f}")
# Out:
# Total Cost: $31.87
